# %%
import networkx as nx
from node import *
from network import *
import math
from numpy.random import normal

# %%
import pandas as pd

# %%
mh_cl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/cl-conv-performance.npy", allow_pickle=True).item())['energy'].to_numpy()
mh_cl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-gsw-performance.npy", allow_pickle=True).item())['energy'].to_numpy()
mh_cl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-nsw-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
mh_cl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/cl-ppo-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
mh_fl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/fl-conv-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
mh_fl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-gsw-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
mh_fl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-nsw-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
mh_fl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/fl-ppo-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
direct_cl = pd.DataFrame(np.load("final-meet/direct-drop/cl-conv-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
direct_fl = pd.DataFrame(np.load("final-meet/direct-drop/fl-conv-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
l_35_cl = pd.DataFrame(np.load("final-meet/leach-0.05-drop/cl-conv-performance.npy",allow_pickle=True).item())['energy'].to_numpy()
l_35_fl =  pd.DataFrame(np.load("final-meet/leach-0.05-drop/fl-conv-performance.npy",allow_pickle=True).item())['energy'].to_numpy()

# %%
residual = plt.figure()
# plt.ylim(0,8000)
plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Residual energy of the network (in Joule)', fontsize=13)
plt.plot(mh_cl_conv,figure=residual, markevery=5 ,color='deepskyblue', marker='X', label='Multi Hop CL in Conv. Network')
plt.plot(mh_cl_gsw, figure=residual, markevery=5 ,color='blue', marker='o', label='Multi Hop CL in Gateway SW-WSN')
plt.plot(mh_cl_nsw, figure=residual, markevery=5 ,color='black', marker='s', label='Multi Hop CL in Normal SW-WSN')
plt.plot(mh_cl_ppo, figure=residual, markevery=5 ,color='red', marker='^', label='Multi Hop CL in vanilla SW-WSN')
plt.plot(direct_cl ,figure=residual, markevery=5 ,color='magenta', marker='*', label='Direct Transmission CL')
plt.plot(l_35_cl ,figure=residual, markevery=2 ,color='darkred', marker='v', label='Leach Transmission P=0.05 CL')

plt.legend()

# plt.savefig('final-meet/residual-cl.eps')
# plt.savefig('final-meet/residual-cl.png')

# %%
residual1 = plt.figure()
plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Residual energy of the network (in Joule)', fontsize=13)
plt.plot(mh_fl_conv,figure=residual1, markevery=5 ,color='deeppink', marker='D', label='Multi Hop FL in Conv. Network')
plt.plot(mh_fl_gsw ,figure=residual1, markevery=5 ,color='orange', marker='P', label='Multi Hop FL in Gateway SW-WSN')
plt.plot(mh_fl_nsw ,figure=residual1, markevery=5 ,color='brown', marker='p', label='Multi Hop FL in Normal SW-WSN')
plt.plot(mh_fl_ppo ,figure=residual1, markevery=5 ,color='darkviolet', marker='H', label='Multi Hop FL in vanilla SW-WSN')
plt.plot(direct_fl ,figure=residual1, markevery=5 ,color='limegreen', marker='+', label='Direct Transmission FL')
plt.plot(l_35_fl ,figure=residual1, markevery=5 ,color='slategrey', marker='<', label='Leach Transmission P=0.05 Fl')

plt.legend()
plt.savefig('final-meet/residual-fl.eps')
plt.savefig('final-meet/residual-fl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
mh_cl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/cl-conv-performance.npy", allow_pickle=True).item())['latency'].to_numpy()
mh_cl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-gsw-performance.npy", allow_pickle=True).item())['latency'].to_numpy()
mh_cl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-nsw-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
mh_cl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/cl-ppo-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
mh_fl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/fl-conv-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
mh_fl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-gsw-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
mh_fl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-nsw-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
mh_fl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/fl-ppo-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
direct_cl = pd.DataFrame(np.load("final-meet/direct-drop/cl-conv-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
direct_fl = pd.DataFrame(np.load("final-meet/direct-drop/fl-conv-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
l_35_cl = pd.DataFrame(np.load("final-meet/leach-0.05-drop/cl-conv-performance.npy",allow_pickle=True).item())['latency'].to_numpy()
l_35_fl =  pd.DataFrame(np.load("final-meet/leach-0.05-drop/fl-conv-performance.npy",allow_pickle=True).item())['latency'].to_numpy()

# %%
latency = plt.figure()

plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Total Data latency (in Seconds)', fontsize=13)
plt.ylim((0,1700))
plt.plot(mh_cl_conv,figure=latency, markevery=5 ,color='deepskyblue', marker='X', label='Multi Hop CL in Conv. Network')
plt.plot(mh_cl_gsw, figure=latency, markevery=5 ,color='blue', marker='o', label='Multi Hop CL in Gateway SW-WSN')
plt.plot(mh_cl_nsw, figure=latency, markevery=5 ,color='black', marker='s', label='Multi Hop CL in Normal SW-WSN')
plt.plot(mh_cl_ppo, figure=latency, markevery=5 ,color='red', marker='^', label='Multi Hop CL in vanilla SW-WSN')
plt.plot(direct_cl ,figure=latency, markevery=5 ,color='magenta', marker='*', label='Direct Transmission CL')
plt.plot(l_35_cl ,figure=latency, markevery=2 ,color='darkred', marker='v', label='Leach Transmission P=0.05 CL')

plt.legend()

plt.savefig('final-meet/latency-cl.eps')
plt.savefig('final-meet/latency-cl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
latencyf = plt.figure()

plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Total Data latency (in Seconds)', fontsize=13)
plt.ylim((0,1700))
plt.plot(mh_fl_conv,figure=latencyf, markevery=5 ,color='deeppink', marker='D', label='Multi Hop FL in Conv. Network')
plt.plot(mh_fl_gsw ,figure=latencyf, markevery=5 ,color='orange', marker='P', label='Multi Hop FL in Gateway SW-WSN')
plt.plot(mh_fl_nsw ,figure=latencyf, markevery=5 ,color='brown', marker='p', label='Multi Hop FL in Normal SW-WSN')
plt.plot(mh_fl_ppo ,figure=latencyf, markevery=5 ,color='darkviolet', marker='H', label='Multi Hop FL in vanilla SW-WSN')
plt.plot(direct_fl ,figure=latencyf, markevery=5 ,color='limegreen', marker='+', label='Direct Transmission FL')
plt.plot(l_35_fl ,figure=latencyf, markevery=5 ,color='slategrey', marker='<', label='Leach Transmission P=0.05 Fl')

plt.legend()
plt.savefig('final-meet/latency-fl.eps')
plt.savefig('final-meet/latency-fl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
mh_cl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/cl-conv-performance.npy", allow_pickle=True).item())['throughput'].to_numpy()
mh_cl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-gsw-performance.npy", allow_pickle=True).item())['throughput'].to_numpy()
mh_cl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-nsw-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
mh_cl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/cl-ppo-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
mh_fl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/fl-conv-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
mh_fl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-gsw-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
mh_fl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-nsw-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
mh_fl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/fl-ppo-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
direct_cl = pd.DataFrame(np.load("final-meet/direct-drop/cl-conv-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
direct_fl = pd.DataFrame(np.load("final-meet/direct-drop/fl-conv-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
l_35_cl = pd.DataFrame(np.load("final-meet/leach-0.05-drop/cl-conv-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()
l_35_fl =  pd.DataFrame(np.load("final-meet/leach-0.05-drop/fl-conv-performance.npy",allow_pickle=True).item())['throughput'].to_numpy()

# %%
throughput = plt.figure()

plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Throughput ratio', fontsize=13)
plt.plot(mh_cl_conv,figure=throughput, markevery=10,linewidth=0.6 ,color='red', marker='X', label='Multi Hop CL in Conv. Network')
plt.plot(mh_cl_gsw, figure=throughput, markevery=10,linewidth=0.6,color='blue', marker='o', label='Multi Hop CL in Gateway SW-WSN')
plt.plot(mh_cl_nsw, figure=throughput, markevery=10,linewidth=0.6,color='orange', marker='s', label='Multi Hop CL in Normal SW-WSN')
plt.plot(mh_cl_ppo, figure=throughput, markevery=10,linewidth=0.6 ,color='green', marker='^', label='Multi Hop CL in vanilla SW-WSN')

plt.plot(direct_cl ,figure=throughput, markevery=5 ,color='magenta', marker='*', label='Direct Transmission CL')
plt.plot(l_35_cl ,figure=throughput, markevery=2 ,color='darkred', marker='v', label='Leach Transmission P=0.05 CL')

plt.ylim(0.8, 0.95)
plt.legend()
plt.savefig('final-meet/throughput-cl.eps')
plt.savefig('final-meet/throughput-cl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
throughput1 = plt.figure()

plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Throughput ratio', fontsize=13)
plt.ylim(0,1)
plt.plot(mh_fl_conv,figure=throughput1, markevery=5 ,color='deeppink', marker='D', label='Multi Hop FL in Conv. Network')
plt.plot(mh_fl_gsw ,figure=throughput1, markevery=5 ,color='orange', marker='P', label='Multi Hop FL in Gateway SW-WSN')
plt.plot(mh_fl_nsw ,figure=throughput1, markevery=5 ,color='brown', marker='p', label='Multi Hop FL in Normal SW-WSN')
plt.plot(mh_fl_ppo ,figure=throughput1, markevery=5 ,color='darkviolet', marker='H', label='Multi Hop FL in vanilla SW-WSN')

plt.plot(direct_fl ,figure=throughput1, markevery=5 ,color='limegreen', marker='+', label='Direct Transmission FL')
plt.plot(l_35_fl ,figure=throughput1, markevery=5 ,color='slategrey', marker='<', label='Leach Transmission P=0.05 Fl')
plt.ylim(0.8, 0.95)
plt.legend()
plt.savefig('final-meet/throughput-fl.eps')
plt.savefig('final-meet/throughput-fl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
mh_cl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/cl-conv-performance.npy", allow_pickle=True).item())['livenodes'].to_numpy()
mh_cl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-gsw-performance.npy", allow_pickle=True).item())['livenodes'].to_numpy()
mh_cl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/cl-nsw-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
mh_cl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/cl-ppo-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
mh_fl_conv = pd.DataFrame(np.load("final-meet/multihop-drop/fl-conv-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
mh_fl_gsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-gsw-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
mh_fl_nsw = pd.DataFrame(np.load("final-meet/multihop-drop/fl-nsw-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
mh_fl_ppo = pd.DataFrame(np.load("final-meet/multihop-drop/fl-ppo-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
direct_cl = pd.DataFrame(np.load("final-meet/direct-drop/cl-conv-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
direct_fl = pd.DataFrame(np.load("final-meet/direct-drop/fl-conv-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
l_35_cl = pd.DataFrame(np.load("final-meet/leach-0.05-drop/cl-conv-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()
l_35_fl =  pd.DataFrame(np.load("final-meet/leach-0.05-drop/fl-conv-performance.npy",allow_pickle=True).item())['livenodes'].to_numpy()

# %%
l=plt.figure()
plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Number of Live Nodes', fontsize=13)
plt.plot(mh_cl_conv,figure=l, markevery=5 ,color='deepskyblue', marker='X', label='Multi Hop CL in Conv. Network')
plt.plot(mh_cl_gsw, figure=l, markevery=5 ,color='blue', marker='o', label='Multi Hop CL in Gateway SW-WSN')
plt.plot(mh_cl_nsw, figure=l, markevery=5 ,color='black', marker='s', label='Multi Hop CL in Normal SW-WSN')
plt.plot(mh_cl_ppo, figure=l, markevery=5 ,color='red', marker='^', label='Multi Hop CL in vanilla SW-WSN')

plt.plot(direct_cl ,figure=l, markevery=5 ,color='magenta', marker='*', label='Direct Transmission CL')
plt.plot(l_35_cl ,figure=l, markevery=5 ,color='darkred', marker='v', label='Leach Transmission P=0.05 CL')
plt.legend()
plt.savefig('final-meet/livenodes-cl.eps')
plt.savefig('final-meet/livenodes-cl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
lf = plt.figure()

plt.xlabel('Number of iterations used for data transmission', fontsize=12)
plt.ylabel('Number of Live Nodes', fontsize=13)

plt.plot(mh_fl_conv,figure=lf, markevery=5 ,color='deeppink', marker='D', label='Multi Hop FL in Conv. Network')
plt.plot(mh_fl_gsw ,figure=lf, markevery=5 ,color='orange', marker='P', label='Multi Hop FL in Gateway SW-WSN')
plt.plot(mh_fl_nsw ,figure=lf, markevery=5 ,color='brown', marker='p', label='Multi Hop FL in Normal SW-WSN')
plt.plot(mh_fl_ppo ,figure=lf, markevery=5 ,color='darkviolet', marker='H', label='Multi Hop FL in vanilla SW-WSN')
plt.plot(direct_fl ,figure=lf, markevery=5 ,color='limegreen', marker='+', label='Direct Transmission FL')
plt.plot(l_35_fl ,figure=lf, markevery=5 ,color='slategrey', marker='<', label='Leach Transmission P=0.05 Fl')

plt.legend()
plt.savefig('final-meet/livenodes-fl.eps')
plt.savefig('final-meet/livenodes-fl.png')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
